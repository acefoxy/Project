# %%
import tweepy #https://github.com/tweepy/tweepy
import unicodecsv
import sys
 
#Twitter API credentials
consumer_key = ""
consumer_secret = ""
access_key = ""
access_secret = ""

 
 
def get_all_tweets(screen_name):
	#Twitter only allows access to a users most recent 3240 tweets with this method
	
	#authorize twitter, initialize tweepy
	auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
	auth.set_access_token(access_key, access_secret)
	api = tweepy.API(auth)
	
	#initialize a list to hold all the tweepy Tweets
	alltweets = []	
	
	#make initial request for most recent tweets (200 is the maximum allowed count)
	new_tweets = api.user_timeline(screen_name = screen_name,count=200)
	
	#save most recent tweets
	alltweets.extend(new_tweets)
	
	#save the id of the oldest tweet less one
	oldest = alltweets[-1].id - 1
	
	#keep grabbing tweets until there are no tweets left to grab
	while len(new_tweets) > 0:
		print("getting tweets before %s" % (oldest))
		
		#all subsiquent requests use the max_id param to prevent duplicates
		new_tweets = api.user_timeline(screen_name = screen_name,count=200,max_id=oldest)
		
		#save most recent tweets
		alltweets.extend(new_tweets)
		
		#update the id of the oldest tweet less one
		oldest = alltweets[-1].id - 1
		
		print("...%s tweets downloaded so far" % (len(alltweets)))
	
	#transform the tweepy tweets into a 2D array that will populate the csv	
	outtweets = [[tweet.id_str, tweet.created_at, tweet.text.encode('utf-8'), tweet.geo, tweet.source, tweet.favorite_count, tweet.retweet_count] for tweet in alltweets]
	
	#write the csv	
	with open('%s_tweets.csv' % screen_name, 'wb') as f:
		writer = unicodecsv.writer(f)
		writer.writerow(["id","created_at","text","geo","source","fav","RT"])
		writer.writerows(outtweets)
	
	pass
 
 
if __name__ == '__main__':
	#pass in the username of the account you want to download
	get_all_tweets('realDonaldTrump')
# Out:
# getting tweets before 959031505145212927
# ...400 tweets downloaded so far
# getting tweets before 948174033882927103
# ...600 tweets downloaded so far
# getting tweets before 936393574433939455
# ...797 tweets downloaded so far
# getting tweets before 926793510723796992
# ...997 tweets downloaded so far
# getting tweets before 920244350268903423
# ...1196 tweets downloaded so far
# getting tweets before 912848241535971330
# ...1396 tweets downloaded so far
# getting tweets before 905512462971232256
# ...1596 tweets downloaded so far
# getting tweets before 896076107094474751
# ...1796 tweets downloaded so far
# getting tweets before 887477071160762368
# ...1996 tweets downloaded so far
# getting tweets before 878031806506848255
# ...2196 tweets downloaded so far
# getting tweets before 865337513245913088
# ...2396 tweets downloaded so far
# getting tweets before 851584729400979455
# ...2596 tweets downloaded so far
# getting tweets before 834377364947816447
# ...
